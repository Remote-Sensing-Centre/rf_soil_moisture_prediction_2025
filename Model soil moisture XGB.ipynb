# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import data_analysis
import numpy as np

# %% [markdown]
# ## Settings

# %%
DATA_FILE = "input_data.csv"
PARAMETER_COLUMNS_SETS = [
    [
        "G_VH_dB",
        "G_VV_dB",
        "projectedLocalIncidenceAngle",
        "assumed_clay_content",
    ],
    [
        "C11_ILSF9_BI1000_dB",
        "C22_ILSF9_BI1000_dB",
        "Surface_r_ILSF9_BI1000",
        "Volume_g_ILSF9_BI1000",
        "Ratio_b_ILSF9_BI1000",
        "projectedLocalIncidenceAngle",
        "assumed_clay_content",
    ],
]
PARAMETERS_SET = 1 # set of parameters from the list above, counting from 0 for the first one
COMMENT = "soil" # string or False (empty string works as False)
SELECTED_PARAMETERS = PARAMETER_COLUMNS_SETS[PARAMETERS_SET]
TARGET = "soil_moisture"
SPLIT_RANDOM_STATE = 727 # integer or None for random split
TUNE_HYPERPARAMETERS = True # True or False to skip
# Model parameters to use without tuning
N_ESTIMATORS = 500
MAX_DEPTH = 10
LEARNING_RATE = 0.01
SUBSAMPLE = 1
COLSAMPLE_BYTREE = 1
REG_ALPHA = 0.1
REG_LAMBDA = 0.1
# Dictionary with parameters to tune
# (will be used only if TUNE_HYPERPARAMETERS = True)
HYPERPARAMETERS_GRID = {
    "xgb__n_estimators": [100, 500, 1000, 1500],
    "xgb__max_depth": [4, 6, 8, 10],
    "xgb__learning_rate": [0.01, 0.1, 0.2], # float [0, 1]
    "xgb__subsample": [0.5, 0.75, 1], # float in (0, 1]
    "xgb__colsample_bytree": [0.5, 1], # float in (0, 1]
    "xgb__reg_alpha": [0, 0.1, 1], # float in [0, infinity)
    "xgb__reg_lambda": [0.1, 1, 2], # float in [0, infinity)
}
LIMIT_DATASET = None # Number of rows or None to skip
EXPORT_MODEL = False # True or False to skip
PLOT_MODEL_PARAMETERS_INFLUENCE = False # True or False to skip

# %%
if not SPLIT_RANDOM_STATE:
    from random import randint

    SPLIT_RANDOM_STATE = randint(1, 1000)
    print(f"Random split state: {SPLIT_RANDOM_STATE}")

# %% [markdown]
# ## Helper functions

# %%
from typing import Tuple

def rounded_range(data: pd.Series, resolution: int = 10) -> Tuple[int, int]:
    bottom = round(data.min() / resolution - 0.5) * resolution
    top = round(data.max() / resolution + 0.5) * resolution

    return (bottom, top)

# %% [markdown]
# ## Set default font for graphs

# %%
mpl.rcParams["font.family"] = "Palatino Linotype"

# %% [markdown]
# ## Read data

# %%
df = pd.read_csv(DATA_FILE, sep=",", engine="python")
df = df[[TARGET] + SELECTED_PARAMETERS]
df.head()

# %%
if LIMIT_DATASET:
    df = df.iloc[0:LIMIT_DATASET]
    df

# %% [markdown]
# ## Exploratory data analysis

# %%
if COMMENT:
    corr_file_name = f"xgb_correlations_set_{PARAMETERS_SET}_{COMMENT}.png"
else:
    corr_file_name = f"xgb_correlations_set_{PARAMETERS_SET}.png"

data_analysis.correlation_matrix_heatmap(df, output_file=corr_file_name)

# %% [markdown]
# ## Prepare data for training

# %%
df.dropna(inplace=True)
df.reset_index(inplace=True, drop=True)

# %%
bins_resolution = 15
_, top_range = rounded_range(df[TARGET], resolution = bins_resolution)
bins = list(range(0, top_range + bins_resolution, bins_resolution))
labels = [f"{bins[i]}-{bins[i+1]}" for i in range(len(bins) - 1)]
df["moisture_bin"] = pd.cut(df[TARGET], bins=bins, labels=labels)

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=SPLIT_RANDOM_STATE)

for train_index, validation_index in split.split(df, df["moisture_bin"]):
    df_stratified_training = df.loc[train_index]
    df_stratified_validation = df.loc[validation_index]

# %%
bin_counts = df_stratified_training["moisture_bin"].value_counts()
bin_counts = bin_counts.sort_index()

plt.figure(figsize=(8, 6), dpi=300)
bars = plt.bar(bin_counts.index.astype(str), bin_counts.values)

for i, bar in enumerate(bars):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        10,
        str(bin_counts.values[i]),
        ha="center",
        va="bottom",
        fontsize=16,
        rotation=90,
        color="black",
    )

plt.title("Measurements counts in soil moisture bins", fontsize=16)
plt.xlabel("Soil moisture bin (%)", fontsize=16)
plt.ylabel("Measurements count", fontsize=16)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis="y", linestyle='--', alpha=0.7)
plt.tight_layout()

if COMMENT:
    distribution_file_name = f"xgb_distribution_set_{PARAMETERS_SET}_{COMMENT}.png"
else:
    distribution_file_name = f"xgb_distribution_set_{PARAMETERS_SET}.png"
plt.savefig(distribution_file_name)

plt.show()

# %%
for dataset in [df_stratified_training, df_stratified_validation]:
    dataset.drop(columns=["moisture_bin", "sample_weight"], inplace=True, errors="ignore")

# %%
X_training, y_training = data_analysis.split_data(df_stratified_training, TARGET)
X_validation, y_validation = data_analysis.split_data(df_stratified_validation, TARGET)

# %% [markdown]
# ## Train model

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from xgboost import XGBRegressor

# %%
if TUNE_HYPERPARAMETERS:
    from sklearn.model_selection import GridSearchCV

    xgb_pipe = Pipeline([
        ("scaler", StandardScaler(with_mean=True, with_std=True)),
        ("xgb", XGBRegressor(objective="reg:squarederror", random_state=SPLIT_RANDOM_STATE, n_jobs=-1))
    ])

    grid_search = GridSearchCV(
        estimator=xgb_pipe,
        param_grid=HYPERPARAMETERS_GRID,
        cv=5,
        scoring="r2",  # "r2" or "neg_mean_squared_error"
        n_jobs=-1,
        verbose=2
    )
    
    grid_search.fit(X_training, y_training)

    print("Best parameters:", grid_search.best_params_)

    xgb_model = grid_search.best_estimator_
else:
    print("Skipped parameters tuning")
    
    xgb_model = Pipeline([
        ("scaler", StandardScaler(with_mean=False, with_std=True)),
        ("xgb", XGBRegressor(
            n_estimators=N_ESTIMATORS,
            max_depth=MAX_DEPTH,
            learning_rate=LEARNING_RATE,
            subsample=SUBSAMPLE,
            colsample_bytree=COLSAMPLE_BYTREE,
            reg_alpha=REG_ALPHA,
            reg_lambda=REG_LAMBDA,
            objective="reg:squarederror",
            random_state=SPLIT_RANDOM_STATE,
            n_jobs=-1
        ))
    ])
    
    xgb_model.fit(X_training, y_training)

# %%
if TUNE_HYPERPARAMETERS:
    N_ESTIMATORS = grid_search.best_params_["xgb__n_estimators"]
    MAX_DEPTH = grid_search.best_params_["xgb__max_depth"]
    LEARNING_RATE = grid_search.best_params_["xgb__learning_rate"]
    SUBSAMPLE = grid_search.best_params_["xgb__subsample"]
    COLSAMPLE_BYTREE = grid_search.best_params_["xgb__colsample_bytree"]
    REG_ALPHA = grid_search.best_params_["xgb__reg_alpha"]
    REG_LAMBDA = grid_search.best_params_["xgb__reg_lambda"]

# %%
if EXPORT_MODEL:
    import joblib
    
    if COMMENT:
        model_file_name = f"xgb_model_set_{PARAMETERS_SET}_{COMMENT}.pkl"
    else:
        model_file_name = f"xgb_model_set_{PARAMETERS_SET}.pkl"
    
    joblib.dump(rf_model, model_file_name)

# %% [markdown]
# ## Analyze model performance

# %%
from sklearn.metrics import root_mean_squared_error
import pandas as pd

# %%
xgb_pred = xgb_model.predict(X_validation)

rmse = root_mean_squared_error(y_validation, xgb_pred)
r_squared = xgb_model.score(X_validation, y_validation)

print("Performance for unknown data:")
print(f"Root mean Squared Error: {rmse:.2f}")
print(f"R-squared value: {r_squared:.2f}")

# %%
xgb_pred_training = xgb_model.predict(X_training)

rmse_training = root_mean_squared_error(y_training, xgb_pred_training)
r_squared_training = xgb_model.score(X_training, y_training)

print("Performance for known data:")
print(f"Mean Squared Error: {rmse_training:.2f}")
print(f"R-squared value: {r_squared_training:.2f}")

# %%
_, top_y = rounded_range(y_validation, resolution=10)
_, top_xgb_pred = rounded_range(xgb_pred, resolution=10)

axis_min = 0
axis_max = max(top_y, top_xgb_pred)

plt.figure(figsize=(10, 8), dpi=300)

sns.scatterplot(x=y_training, y=xgb_model.predict(X_training), color="red", label="Predictions on train dataset")
sns.scatterplot(x=y_validation, y=xgb_pred, color="blue", label="Predictions on validation dataset")
p = sns.regplot(x=y_validation, y=xgb_pred, scatter=False, color="blue", label="Regression line (validation)")
slope, intercept, r, p, sterr = scipy.stats.linregress(x=p.get_lines()[0].get_xdata(), y=p.get_lines()[0].get_ydata())

plt.plot([axis_min, axis_max], [axis_min, axis_max], "r--", label="Perfect prediction")

plt.xlabel("Measured soil moisture (%)", fontsize=16)
plt.ylabel("Predicted soil moisture (%)", fontsize=16)
plt.title(f"XGBoost regression prediction of soil moisture\nRMSE: {rmse:.2f}, R²: {r_squared:.2f}, y = {slope:.3f} x + {intercept:.3f}", fontsize=16, fontweight="bold")
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)
plt.grid(True)
plt.xlim(axis_min, axis_max)
plt.ylim(axis_min, axis_max)
plt.gca().set_aspect("equal", adjustable="box")
plt.tight_layout()

if COMMENT:
    prediction_test_file_name = f"xgb_prediction_set_{PARAMETERS_SET}_{COMMENT}.png"
else:
    prediction_test_file_name = f"xgb_prediction_set_{PARAMETERS_SET}.png"

plt.savefig(prediction_test_file_name)
plt.show()

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(xgb_model, X_training, y_training, cv=5, scoring="neg_root_mean_squared_error")
print(f"Cross-validated RMSE: {-scores.mean():.2f} +/- {scores.std():.2f}")

# %%
if PLOT_MODEL_PARAMETERS_INFLUENCE:
    train_errors = []
    test_errors = []
    
    var_range = range(10, 3020, 100)
    
    for n_estim in var_range:
        model = Pipeline([
            ("scaler", StandardScaler(with_mean=False, with_std=True)),
            ("xgb", XGBRegressor(
                n_estimators=n_estim,
                max_depth=MAX_DEPTH,
                learning_rate=LEARNING_RATE,
                subsample=SUBSAMPLE,
                colsample_bytree=COLSAMPLE_BYTREE,
                reg_alpha=REG_ALPHA,
                reg_lambda=REG_LAMBDA,
                objective="reg:squarederror",
                random_state=SPLIT_RANDOM_STATE,
                n_jobs=-1
            ))
        ])
        
        model.fit(X_training, y_training)
        
        train_pred = model.predict(X_training)
        test_pred = model.predict(X_validation)
        
        train_rmse = root_mean_squared_error(y_training, train_pred)
        test_rmse = root_mean_squared_error(y_validation, test_pred)
        
        train_errors.append(train_rmse)
        test_errors.append(test_rmse)
    plt.plot(var_range, train_errors, label="Train data")
    plt.plot(var_range, test_errors, label="Test data")
    plt.xlabel("n_estimators")
    plt.ylabel("RMSE")
    plt.title("RMSE n_estimators")
    plt.legend()
    plt.show()

# %%
if PLOT_MODEL_PARAMETERS_INFLUENCE:
    train_errors = []
    test_errors = []
    
    var_range = range(0, 6, 1)
    
    for max_depth in var_range:
        model = Pipeline([
            ("scaler", StandardScaler(with_mean=False, with_std=True)),
            ("xgb", XGBRegressor(
                n_estimators=N_ESTIMATORS,
                max_depth=max_depth,
                learning_rate=LEARNING_RATE,
                subsample=SUBSAMPLE,
                colsample_bytree=COLSAMPLE_BYTREE,
                reg_alpha=REG_ALPHA,
                reg_lambda=REG_LAMBDA,
                objective="reg:squarederror",
                random_state=SPLIT_RANDOM_STATE,
                n_jobs=-1
            ))
        ])
        
        model.fit(X_training, y_training)
        
        train_pred = model.predict(X_training)
        test_pred = model.predict(X_validation)
        
        train_rmse = root_mean_squared_error(y_training, train_pred)
        test_rmse = root_mean_squared_error(y_validation, test_pred)
        
        train_errors.append(train_rmse)
        test_errors.append(test_rmse)
    plt.plot(var_range, train_errors, label="Train data")
    plt.plot(var_range, test_errors, label="Test data")
    plt.xlabel("max_depth")
    plt.ylabel("RMSE")
    plt.title("RMSE max_depth")
    plt.legend()
    plt.show()

# %%
if PLOT_MODEL_PARAMETERS_INFLUENCE:
    train_errors = []
    test_errors = []
    
    var_range = [i / 10 for i in range(0, 11, 1)]
    
    for learning_rate in var_range:
        model = Pipeline([
            ("scaler", StandardScaler(with_mean=False, with_std=True)),
            ("xgb", XGBRegressor(
                n_estimators=N_ESTIMATORS,
                max_depth=MAX_DEPTH,
                learning_rate=learning_rate,
                subsample=SUBSAMPLE,
                colsample_bytree=COLSAMPLE_BYTREE,
                reg_alpha=REG_ALPHA,
                reg_lambda=REG_LAMBDA,
                objective="reg:squarederror",
                random_state=SPLIT_RANDOM_STATE,
                n_jobs=-1
            ))
        ])
        
        model.fit(X_training, y_training)
        
        train_pred = model.predict(X_training)
        test_pred = model.predict(X_validation)
        
        train_rmse = root_mean_squared_error(y_training, train_pred)
        test_rmse = root_mean_squared_error(y_validation, test_pred)
        
        train_errors.append(train_rmse)
        test_errors.append(test_rmse)
    plt.plot(var_range, train_errors, label="Train data")
    plt.plot(var_range, test_errors, label="Test data")
    plt.xlabel("learning_rate")
    plt.ylabel("RMSE")
    plt.title("RMSE learning_rate")
    plt.legend()
    plt.show()

# %%
if PLOT_MODEL_PARAMETERS_INFLUENCE:
    train_errors = []
    test_errors = []
    
    var_range = [i / 10 for i in range(0, 11, 1)]
    
    for subsample in var_range:
        model = Pipeline([
            ("scaler", StandardScaler(with_mean=False, with_std=True)),
            ("xgb", XGBRegressor(
                n_estimators=N_ESTIMATORS,
                max_depth=MAX_DEPTH,
                learning_rate=LEARNING_RATE,
                subsample=subsample,
                colsample_bytree=COLSAMPLE_BYTREE,
                reg_alpha=REG_ALPHA,
                reg_lambda=REG_LAMBDA,
                objective="reg:squarederror",
                random_state=SPLIT_RANDOM_STATE,
                n_jobs=-1
            ))
        ])
        
        model.fit(X_training, y_training)
        
        train_pred = model.predict(X_training)
        test_pred = model.predict(X_validation)
        
        train_rmse = root_mean_squared_error(y_training, train_pred)
        test_rmse = root_mean_squared_error(y_validation, test_pred)
        
        train_errors.append(train_rmse)
        test_errors.append(test_rmse)
    plt.plot(var_range, train_errors, label="Train data")
    plt.plot(var_range, test_errors, label="Test data")
    plt.xlabel("subsample")
    plt.ylabel("RMSE")
    plt.title("RMSE subsample")
    plt.legend()
    plt.show()

# %%
if PLOT_MODEL_PARAMETERS_INFLUENCE:
    train_errors = []
    test_errors = []
    
    var_range = [i / 10 for i in range(0, 11, 1)]
    
    for bytree in var_range:
        model = Pipeline([
            ("scaler", StandardScaler(with_mean=False, with_std=True)),
            ("xgb", XGBRegressor(
                n_estimators=N_ESTIMATORS,
                max_depth=MAX_DEPTH,
                learning_rate=LEARNING_RATE,
                subsample=SUBSAMPLE,
                colsample_bytree=bytree,
                reg_alpha=REG_ALPHA,
                reg_lambda=REG_LAMBDA,
                objective="reg:squarederror",
                random_state=SPLIT_RANDOM_STATE,
                n_jobs=-1
            ))
        ])
        
        model.fit(X_training, y_training)
        
        train_pred = model.predict(X_training)
        test_pred = model.predict(X_validation)
        
        train_rmse = root_mean_squared_error(y_training, train_pred)
        test_rmse = root_mean_squared_error(y_validation, test_pred)
        
        train_errors.append(train_rmse)
        test_errors.append(test_rmse)
    plt.plot(var_range, train_errors, label="Train data")
    plt.plot(var_range, test_errors, label="Test data")
    plt.xlabel("colsample_bytree")
    plt.ylabel("RMSE")
    plt.title("RMSE colsample_bytree")
    plt.legend()
    plt.show()

# %%
if PLOT_MODEL_PARAMETERS_INFLUENCE:
    train_errors = []
    test_errors = []
    
    var_range = [i / 10 for i in range(0, 21, 2)]
    
    for reg_alpha in var_range:
        model = Pipeline([
            ("scaler", StandardScaler(with_mean=False, with_std=True)),
            ("xgb", XGBRegressor(
                n_estimators=N_ESTIMATORS,
                max_depth=MAX_DEPTH,
                learning_rate=LEARNING_RATE,
                subsample=SUBSAMPLE,
                colsample_bytree=COLSAMPLE_BYTREE,
                reg_alpha=reg_alpha,
                reg_lambda=REG_LAMBDA,
                objective="reg:squarederror",
                random_state=SPLIT_RANDOM_STATE,
                n_jobs=-1
            ))
        ])
        
        model.fit(X_training, y_training)
        
        train_pred = model.predict(X_training)
        test_pred = model.predict(X_validation)
        
        train_rmse = root_mean_squared_error(y_training, train_pred)
        test_rmse = root_mean_squared_error(y_validation, test_pred)
        
        train_errors.append(train_rmse)
        test_errors.append(test_rmse)
    plt.plot(var_range, train_errors, label="Train data")
    plt.plot(var_range, test_errors, label="Test data")
    plt.xlabel("reg_alpha")
    plt.ylabel("RMSE")
    plt.title("RMSE reg_alpha")
    plt.legend()
    plt.show()

# %%
if PLOT_MODEL_PARAMETERS_INFLUENCE:
    train_errors = []
    test_errors = []
    
    var_range = [i / 10 for i in range(0, 101, 10)]
    
    for reg_lambda in var_range:
        model = Pipeline([
            ("scaler", StandardScaler(with_mean=False, with_std=True)),
            ("xgb", XGBRegressor(
                n_estimators=N_ESTIMATORS,
                max_depth=MAX_DEPTH,
                learning_rate=LEARNING_RATE,
                subsample=SUBSAMPLE,
                colsample_bytree=COLSAMPLE_BYTREE,
                reg_alpha=REG_ALPHA,
                reg_lambda=reg_lambda,
                objective="reg:squarederror",
                random_state=SPLIT_RANDOM_STATE,
                n_jobs=-1
            ))
        ])
        
        model.fit(X_training, y_training)
        
        train_pred = model.predict(X_training)
        test_pred = model.predict(X_validation)
        
        train_rmse = root_mean_squared_error(y_training, train_pred)
        test_rmse = root_mean_squared_error(y_validation, test_pred)
        
        train_errors.append(train_rmse)
        test_errors.append(test_rmse)
    plt.plot(var_range, train_errors, label="Train data")
    plt.plot(var_range, test_errors, label="Test data")
    plt.xlabel("reg_lambda")
    plt.ylabel("RMSE")
    plt.title("RMSE reg_lambda")
    plt.legend()
    plt.show()

# %% [markdown]
# ## Residuals analysis

# %%
residuals = y_validation - xgb_pred

# %%
print("Residuals statistics:")
print(f"Mean: {float(np.mean(residuals)):.2f}")
print(f"MAE: {float(np.mean(np.abs(residuals))):.2f}")
print(f"RMSE: {float(np.sqrt(np.mean(residuals**2))):.2f}")
print(f"Skew: {float(scipy.stats.skew(residuals, bias=False)):.2f}")

# %%
plt.figure(figsize=(10, 8), dpi=300)

bin_edges = np.arange(residuals.min() - (residuals.min() % 2), residuals.max() + 2, 2)

plt.hist(residuals, bins=bin_edges, density=True, color="blue", rwidth=0.99)

plt.title("XGBoost regression - histogram of residuals", fontsize=16, fontweight="bold")
plt.xlabel("Residual", fontsize=16)
plt.ylabel("Density", fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlim(-20, 20)
plt.grid(visible=True, axis="y")
plt.tight_layout()

if COMMENT:
    residuals_file_name = f"xgb_residuals_hist_{PARAMETERS_SET}_{COMMENT}.png"
else:
    residuals_file_name = f"xgb_residuals_hist_{PARAMETERS_SET}.png"

plt.savefig(residuals_file_name)
plt.show()

# %% [markdown]
# ## Generate output file

# %%
if COMMENT:
    text_file_name = f"xgb_parameters_set_{PARAMETERS_SET}_{COMMENT}.txt"
else:
    text_file_name = f"xgb_parameters_set_{PARAMETERS_SET}.txt"

with open(text_file_name, "w") as f:
    f.write("Input parameters:\n")
    for parameter in SELECTED_PARAMETERS:
        f.write(f"{parameter}\n")
    if COMMENT:
        f.write(f"\nComment: {COMMENT}\n")
    f.write("\nModel parameters:\n")
    f.write(f"n_estimators: {N_ESTIMATORS}\n")
    f.write(f"max_depthn: {MAX_DEPTH}\n")
    f.write(f"learning_rate: {LEARNING_RATE}\n")
    f.write(f"subsample: {SUBSAMPLE}\n")
    f.write(f"colsample_bytree: {COLSAMPLE_BYTREE}\n")
    f.write(f"reg_alpha: {REG_ALPHA}\n")
    f.write(f"reg_lambda: {REG_LAMBDA}\n\n")
    f.write("Performance for unknown data:\n")
    f.write(f"Root Mean Squared Error: {rmse:.2f}\n")
    f.write(f"R-squared value: {r_squared:.2f}\n")
    f.write("\nPerformance for known data:\n")
    f.write(f"Root Mean Squared Error: {rmse_training:.2f}\n")
    f.write(f"R-squared value: {r_squared_training:.2f}\n")
    f.write(f"\nCross-validated RMSE: {-scores.mean():.2f} +/- {scores.std():.2f}\n")
    f.write("\nResiduals statistics:\n")
    f.write(f"Mean: {float(np.mean(residuals)):.2f}\n")
    f.write(f"MAE: {float(np.mean(np.abs(residuals))):.2f}\n")
    f.write(f"RMSE: {float(np.sqrt(np.mean(residuals**2))):.2f}\n")
    f.write(f"Skew: {float(scipy.stats.skew(residuals, bias=False)):.2f}\n")
