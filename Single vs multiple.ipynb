# %%
import pandas as pd

# %%
DATA_FILE = "input_data.csv"

# %%
df = pd.read_csv(DATA_FILE, sep=",", engine="python")
df = df.dropna()
df.head()
# Out:
#    study_area    id   Latitude  Longitude orbit  incidence_angle field_id  \
# 0  KEDZIERZYN  KG01  50.323410  18.129482  A175            36.95       KG
# 1  KEDZIERZYN  KG02  50.323691  18.129680  A175            36.95       KG
# 2  KEDZIERZYN  KG03  50.323996  18.129890  A175            36.95       KG
# 3  KEDZIERZYN  KG04  50.323856  18.130370  A175            36.95       KG
# 4  KEDZIERZYN  KG05  50.323531  18.130193  A175            36.95       KG
#
#          date  soil_moisture  G_VH_dB  ...  Surface_r_ILSF9_BI1000  \
# 0  12.10.2024          17.80   -18.92  ...                 -15.302
# 1  12.10.2024          18.26   -18.41  ...                 -15.678
# 2  12.10.2024          24.14   -18.74  ...                 -14.058
# 3  12.10.2024          19.57   -18.05  ...                 -14.180
# 4  12.10.2024          20.67   -19.09  ...                 -16.659
#
#    Volume_g_ILSF9_BI1000  Ratio_b_ILSF9_BI1000  \
# 0                -17.034                 1.732
# 1                -16.317                 0.639
# 2                -16.169                 2.111
# 3                -16.217                 2.037
# 4                -16.214                -0.445
#
#    projectedLocalIncidenceAngle_OLD  soil_complex  soil_type  soil_texture  \
# 0                             36.63             8          F            bc
# 1                             37.37             8          F            bc
# 2                             37.41             8          F            bc
# 3                             36.33             8          F            bc
# 4                             37.04             8          F            bc
#
#            top_texture  range_clay_content assumed_clay_content
# 0  mady bardzo ciężkie             pow. 50                 50.0
# 1  mady bardzo ciężkie             pow. 50                 50.0
# 2  mady bardzo ciężkie             pow. 50                 50.0
# 3  mady bardzo ciężkie             pow. 50                 50.0
# 4  mady bardzo ciężkie             pow. 50                 50.0
#
# [5 rows x 25 columns]

# %%
df["field_id"].value_counts()
# Out:
# field_id
# OR     49
# BGE    40
# OL     30
# ON     30
# OE     24
#        ..
# KKL     2
# KZ      1
# JB      1
# BO      1
# BZ      1
# Name: count, Length: 92, dtype: int64

# %%
df["id"].value_counts().head(50)
# Out:
# id
# OR14     5
# OR13     5
# BGE06    4
# BGE05    4
# BGE01    4
# BGE02    4
# OR01     4
# OR05     4
# OR04     4
# OR03     4
# BGE07    4
# OR02     4
# BGE03    4
# OR11     4
# BGE08    4
# BGE09    4
# OT01     4
# BGE04    4
# BGE10    4
# OT06     3
# OZ19     3
# OT03     3
# OT05     3
# OT02     3
# OR12     3
# OE12     2
# OE03     2
# OJ03     2
# OZ10     2
# OL21     2
# OZ12     2
# OL19     2
# OR06     2
# OR07     2
# OI03     2
# OI04     2
# OL13     2
# OL14     2
# OL15     2
# BGI05    2
# BGI06    2
# OZ11     2
# OZ13     2
# OL20     2
# OL18     2
# OE02     2
# OE01     2
# OJ01     2
# OZ14     2
# OZ15     2
# Name: count, dtype: int64

# %%
df[df["id"] == "BGE06"]
# Out:
#     study_area     id   Latitude  Longitude orbit  incidence_angle field_id  \
# 754    BRWINOW  BGE06  52.145608     20.699  A029            32.56      BGE
# 755    BRWINOW  BGE06  52.145608     20.699  A029            32.56      BGE
# 756    BRWINOW  BGE06  52.145608     20.699  A102            41.14      BGE
# 757    BRWINOW  BGE06  52.145608     20.699  A102            41.14      BGE
#
#            date  soil_moisture  G_VH_dB  ...  Surface_r_ILSF9_BI1000  \
# 754  21.03.2025          13.96   -26.29  ...                 -18.190
# 755  21.03.2025          13.96   -26.29  ...                 -18.190
# 756  25.03.2025          16.19   -21.53  ...                 -13.236
# 757  25.03.2025          16.19   -21.53  ...                 -13.236
#
#      Volume_g_ILSF9_BI1000  Ratio_b_ILSF9_BI1000  \
# 754                -18.607                 0.418
# 755                -18.607                 0.418
# 756                -18.567                 5.331
# 757                -18.567                 5.331
#
#      projectedLocalIncidenceAngle_OLD  soil_complex  soil_type  soil_texture  \
# 754                            32.599             6         Dz         ps:gs
# 755                            32.599             6         Dz         ps:gs
# 756                            41.234             6         Dz         ps:gs
# 757                            41.234             6         Dz         ps:gs
#
#                top_texture  range_clay_content assumed_clay_content
# 754  piaski słabogliniaste              5 - 10                  7.5
# 755  piaski słabogliniaste              5 - 10                  7.5
# 756  piaski słabogliniaste              5 - 10                  7.5
# 757  piaski słabogliniaste              5 - 10                  7.5
#
# [4 rows x 25 columns]

# %%
df[df["field_id"] == "OL"]
# Out:
#     study_area    id   Latitude  Longitude orbit  incidence_angle field_id  \
# 330      OBORY  OL16  52.080624  21.169103  A029            34.55       OL
# 331      OBORY  OL16  52.080624  21.169103  A102            42.91       OL
# 332      OBORY  OL17  52.081433  21.169106  A029            34.55       OL
# 333      OBORY  OL17  52.081433  21.169106  A102            42.91       OL
# 407      OBORY  OL07  52.083602  21.160942  A029            34.55       OL
# 408      OBORY  OL07  52.083602  21.160942  A102            42.91       OL
# 409      OBORY  OL08  52.083872  21.160797  A029            34.55       OL
# 410      OBORY  OL08  52.083872  21.160797  A102            42.91       OL
# 411      OBORY  OL09  52.084501  21.160945  A029            34.55       OL
# 412      OBORY  OL09  52.084501  21.160945  A102            42.91       OL
# 413      OBORY  OL10  52.084319  21.162404  A029            34.55       OL
# 414      OBORY  OL10  52.084319  21.162404  A102            42.91       OL
# 415      OBORY  OL11  52.084050  21.161819  A029            34.55       OL
# 416      OBORY  OL11  52.084050  21.161819  A102            42.91       OL
# 417      OBORY  OL12  52.083781  21.161672  A029            34.55       OL
# 418      OBORY  OL12  52.083781  21.161672  A102            42.91       OL
# 694      OBORY  OL13  52.080173  21.169539  A029            34.55       OL
# 695      OBORY  OL13  52.080173  21.169539  A102            42.91       OL
# 696      OBORY  OL14  52.080443  21.169686  A029            34.55       OL
# 697      OBORY  OL14  52.080443  21.169686  A102            42.91       OL
# 698      OBORY  OL15  52.080713  21.169687  A029            34.55       OL
# 699      OBORY  OL15  52.080713  21.169687  A102            42.91       OL
# 700      OBORY  OL18  52.080981  21.170418  A029            34.55       OL
# 701      OBORY  OL18  52.080981  21.170418  A102            42.91       OL
# 702      OBORY  OL19  52.080532  21.170270  A029            34.55       OL
# 703      OBORY  OL19  52.080532  21.170270  A102            42.91       OL
# 704      OBORY  OL20  52.080352  21.170707  A029            34.55       OL
# 705      OBORY  OL20  52.080352  21.170707  A102            42.91       OL
# 706      OBORY  OL21  52.080172  21.170561  A029            34.55       OL
# 707      OBORY  OL21  52.080172  21.170561  A102            42.91       OL
#
#            date  soil_moisture  G_VH_dB  ...  Surface_r_ILSF9_BI1000  \
# 330  27.08.2024          17.42   -22.28  ...                 -15.102
# 331  01.09.2024          16.28   -23.68  ...                 -20.560
# 332  27.08.2024          21.23   -25.56  ...                 -17.462
# 333  01.09.2024          16.75   -23.55  ...                 -18.287
# 407  27.08.2024          36.52   -20.95  ...                 -20.583
# 408  01.09.2024          27.88   -23.23  ...                 -21.834
# 409  27.08.2024          29.09   -21.37  ...                 -19.691
# 410  01.09.2024          21.05   -23.15  ...                 -20.181
# 411  27.08.2024          33.34   -24.91  ...                 -17.742
# 412  01.09.2024          21.22   -24.94  ...                 -19.505
# 413  27.08.2024          32.38   -23.76  ...                 -20.971
# 414  01.09.2024          26.11   -25.07  ...                 -19.574
# 415  27.08.2024          29.27   -22.28  ...                 -19.230
# 416  01.09.2024          27.31   -24.70  ...                 -19.403
# 417  27.08.2024          28.13   -23.10  ...                 -19.945
# 418  01.09.2024          26.03   -25.38  ...                 -18.533
# 694  27.08.2024          15.26   -22.62  ...                 -16.047
# 695  01.09.2024          13.54   -23.70  ...                 -21.736
# 696  27.08.2024          15.78   -22.12  ...                 -16.811
# 697  01.09.2024          12.49   -24.49  ...                 -20.705
# 698  27.08.2024          19.43   -22.16  ...                 -18.649
# 699  01.09.2024          14.94   -23.93  ...                 -19.321
# 700  27.08.2024          15.21   -21.23  ...                 -20.683
# 701  01.09.2024          13.64   -23.18  ...                 -18.016
# 702  27.08.2024          17.17   -23.04  ...                 -19.305
# 703  01.09.2024          14.18   -24.46  ...                 -19.352
# 704  27.08.2024          15.70   -23.30  ...                 -19.744
# 705  01.09.2024          12.91   -24.02  ...                 -19.810
# 706  27.08.2024          18.56   -22.86  ...                 -19.799
# 707  01.09.2024          14.29   -24.24  ...                 -24.427
#
#      Volume_g_ILSF9_BI1000  Ratio_b_ILSF9_BI1000  \
# 330                -19.210                 4.108
# 331                -20.654                 0.093
# 332                -18.314                 0.853
# 333                -20.385                 2.098
# 407                -16.096                -4.487
# 408                -19.110                -2.725
# 409                -16.105                -3.586
# 410                -19.700                -0.480
# 411                -17.891                 0.149
# 412                -20.717                 1.212
# 413                -17.458                -3.513
# 414                -20.454                 0.879
# 415                -17.753                -1.476
# 416                -20.571                 1.168
# 417                -17.296                -2.649
# 418                -20.140                 1.606
# 694                -17.550                 1.503
# 695                -20.156                -1.581
# 696                -17.618                 0.807
# 697                -21.662                 0.957
# 698                -17.467                -1.182
# 699                -22.813                 3.491
# 700                -16.797                -3.886
# 701                -20.613                 2.598
# 702                -17.748                -1.556
# 703                -22.066                 2.714
# 704                -17.683                -2.061
# 705                -20.146                 0.336
# 706                -17.490                -2.310
# 707                -19.471                -4.956
#
#      projectedLocalIncidenceAngle_OLD  soil_complex  soil_type  soil_texture  \
# 330                             33.48             2          F      pgmp.płz
# 331                             42.94             2          F      pgmp.płz
# 332                             34.57             2          F      pgmp.płz
# 333                             42.92             2          F      pgmp.płz
# 407                             36.80             2         zF           płz
# 408                             45.10             2         zF           płz
# 409                             34.12             2         zF           płz
# 410                             42.25             2         zF           płz
# 411                             30.98             2         zF           płz
# 412                             39.39             2         zF           płz
# 413                             34.25             2         zF           płz
# 414                             42.62             2         zF           płz
# 415                             34.59             2         zF           płz
# 416                             42.91             2         zF           płz
# 417                             33.50             2         zF           płz
# 418                             42.02             2         zF           płz
# 694                             34.71             5          F         ps:gc
# 695                             43.05             5          F         ps:gc
# 696                             33.72             5          F         ps:gc
# 697                             42.08             5          F         ps:gc
# 698                             34.01             5          F         ps:gc
# 699                             42.19             5          F         ps:gc
# 700                             37.58             5          F         ps:gc
# 701                             45.91             5          F         ps:gc
# 702                             34.42             5          F         ps:gc
# 703                             42.70             5          F         ps:gc
# 704                             34.63             5          F         ps:gc
# 705                             42.94             5          F         ps:gc
# 706                             33.63             5          F         ps:gc
# 707                             42.13             5          F         ps:gc
#
#                 top_texture  range_clay_content assumed_clay_content
# 330  piaski gliniaste mocne             15 - 20                 17.5
# 331  piaski gliniaste mocne             15 - 20                 17.5
# 332  piaski gliniaste mocne             15 - 20                 17.5
# 333  piaski gliniaste mocne             15 - 20                 17.5
# 407             pyły zwykłe              0 - 35                 17.5
# 408             pyły zwykłe              0 - 35                 17.5
# 409             pyły zwykłe              0 - 35                 17.5
# 410             pyły zwykłe              0 - 35                 17.5
# 411             pyły zwykłe              0 - 35                 17.5
# 412             pyły zwykłe              0 - 35                 17.5
# 413             pyły zwykłe              0 - 35                 17.5
# 414             pyły zwykłe              0 - 35                 17.5
# 415             pyły zwykłe              0 - 35                 17.5
# 416             pyły zwykłe              0 - 35                 17.5
# 417             pyły zwykłe              0 - 35                 17.5
# 418             pyły zwykłe              0 - 35                 17.5
# 694   piaski słabogliniaste              5 - 10                  7.5
# 695   piaski słabogliniaste              5 - 10                  7.5
# 696   piaski słabogliniaste              5 - 10                  7.5
# 697   piaski słabogliniaste              5 - 10                  7.5
# 698   piaski słabogliniaste              5 - 10                  7.5
# 699   piaski słabogliniaste              5 - 10                  7.5
# 700   piaski słabogliniaste              5 - 10                  7.5
# 701   piaski słabogliniaste              5 - 10                  7.5
# 702   piaski słabogliniaste              5 - 10                  7.5
# 703   piaski słabogliniaste              5 - 10                  7.5
# 704   piaski słabogliniaste              5 - 10                  7.5
# 705   piaski słabogliniaste              5 - 10                  7.5
# 706   piaski słabogliniaste              5 - 10                  7.5
# 707   piaski słabogliniaste              5 - 10                  7.5
#
# [30 rows x 25 columns]
